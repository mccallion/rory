# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
from fastai.vision.all import *
import numpy as np
import shutil
import os

# %%
data_dir   = untar_data(URLs.COCO_SAMPLE)
img_dir    = data_dir/"train_sample"
annos_file = data_dir/'annotations/train_sample_allannos.json'

# %% [markdown]
# Get subset:

# %%
fns, annos = get_annotations(annos_file)

# %%
len(fns), fns[0]
# Out:
# (21837, '000000318219.jpg')

# %%
subset_pct = .001

# %%
subset = np.random.choice(fns, int(len(fns)*subset_pct))

# %%
subset
# Out:
# array(['000000524333.jpg', '000000485188.jpg', '000000261225.jpg',
#        '000000170975.jpg', '000000060246.jpg', '000000085183.jpg',
#        '000000527139.jpg', '000000160330.jpg', '000000010844.jpg',
#        '000000086560.jpg', '000000391332.jpg', '000000298299.jpg',
#        '000000243213.jpg', '000000534733.jpg', '000000391891.jpg',
#        '000000082273.jpg', '000000463800.jpg', '000000108575.jpg',
#        '000000116678.jpg', '000000256444.jpg', '000000124824.jpg'],
#       dtype='<U16')

# %% [markdown]
# Test one:

# %%
shutil.copy(img_dir/subset[0], img_dir/"subset"/subset[0])
# Out:
# Path('/home/rory/.fastai/data/coco_sample/train_sample/subset/000000524333.jpg')

# %%
from PIL import Image
from torchvision.transforms import ToTensor

tim = ToTensor()(Image.open(img_dir/"subset"/subset[0]))
ctx = show_image(tim, figsize=[10,10])

# %% [markdown]
# Copy full subset amnt:

# %%
subset_pct = .1

# %%
subset = np.random.choice(fns, int(len(fns)*subset_pct))

# %%
len(subset)
# Out:
# 2183

# %%
for fn in subset: shutil.copy(img_dir/fn, img_dir/"subset"/fn)
