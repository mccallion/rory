# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Improvements-I'd-like-to-make-to-coco_labeledbboxes" data-toc-modified-id="Improvements-I'd-like-to-make-to-coco_labeledbboxes-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Improvements I'd like to make to coco_labeledbboxes</a></span></li><li><span><a href="#Building-&amp;-training-the-model" data-toc-modified-id="Building-&amp;-training-the-model-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Building &amp; training the model</a></span><ul class="toc-item"><li><span><a href="#Data" data-toc-modified-id="Data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Data</a></span></li><li><span><a href="#Model" data-toc-modified-id="Model-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Model</a></span></li><li><span><a href="#Train" data-toc-modified-id="Train-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Train</a></span></li><li><span><a href="#View-Results" data-toc-modified-id="View-Results-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>View Results</a></span></li><li><span><a href="#Notes-&amp;-Work" data-toc-modified-id="Notes-&amp;-Work-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Notes &amp; Work</a></span><ul class="toc-item"><li><span><a href="#Loss-Notes" data-toc-modified-id="Loss-Notes-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Loss Notes</a></span></li><li><span><a href="#Loss-Work" data-toc-modified-id="Loss-Work-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Loss Work</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Improvements I'd like to make to coco_labeledbboxes

# %% [markdown]
# 1. Get `dls.show_batch()` working.
# 2. Get `learner.show_results()` working.
# 3. Implement metrics for RMSE and CEL.

# %% [markdown]
# # Building & training the model

# %% [markdown]
# ## Data

# %%
from fastai.vision.all import *


### Params ###
im_size      = 224
batch_size   = 64
path         = Path('/home/rory/data/coco2017')
valid_split  = .15


### Load data (singles) ###
# Grab cols
def grab_cols(df, cols):
    """Expects: DataFrame df; str or list of strs cols. Returns: L or an LoL."""
    def _grab_col(df, col):
        return L((ColReader(col)(df)).to_list())
    
    if isinstance(cols, str): return _grab_col(df, cols)
    if len(cols)==1: return _grab_col(df, cols)
    if len(cols)>=2:
        r=L()
        for c in cols:
            r.append(_grab_col(df,c))
        return r
df = pd.read_pickle(path/'singles.pkl')
imp, lbl, bbox = grab_cols(df, ['im','lbl','bbox'])
bbox = bbox.map(lambda x:list(x)) # fixed pickle bug; lists incorrectly unpickled as tups
# Create getters for pipeline
imp2lbl  = {p:l for p,l in zip(imp,lbl)}
imp2bbox = {p:b for p,b in zip(imp,bbox)}
def get_lbl(p):  return imp2lbl[p]
def get_bbox(p): return imp2bbox[p]


### Datasets ###
dss_tfms = [[PILImage.create],
            [get_bbox, TensorBBox.create],
            [get_lbl, Categorize()]]
splits = RandomSplitter(valid_split)(imp)
dss = Datasets(imp, tfms=dss_tfms, splits=splits)


### DataLoaders ###
cpu_tfms = [BBoxLabeler(),
            PointScaler(),
            ToTensor(),
            Resize(im_size, method='squish')]
gpu_tfms = [IntToFloatTensor(), Normalize.from_stats(*imagenet_stats)]
dls = dss.dataloaders(bs=batch_size, after_item=cpu_tfms, after_batch=gpu_tfms)
dls.n_inp = 1

# %%
tuple_tfm??
# Out:
# Object `tuple_tfm` not found.

# %%
dls.valid.show_batch()

# %%
b = dls.one_batch()
im, bb, lbl = b
d = dls.decode_batch(b)
d[0]
# Out:
# (TensorImage([[[ 38,  56,  44,  ...,   5,   7,   9],
#           [ 42,  56,  68,  ...,   8,   8,  11],
#           [ 32,  31,  51,  ...,  12,  11,  15],
#           ...,
#           [132, 139, 168,  ..., 150, 159, 158],
#           [145, 146, 173,  ..., 154, 158, 154],
#           [141, 137, 168,  ..., 153, 158, 155]],
#
#          [[ 62,  79,  68,  ...,  12,  14,  16],
#           [ 65,  80,  91,  ...,  15,  15,  18],
#           [ 54,  52,  71,  ...,  19,  18,  22],
#           ...,
#           [155, 160, 186,  ..., 179, 186, 184],
#           [173, 172, 197,  ..., 182, 184, 179],
#           [169, 163, 192,  ..., 181, 184, 180]],
#
#          [[ 49,  66,  55,  ...,  18,  20,  22],
#           [ 53,  67,  78,  ...,  21,  21,  25],
#           [ 42,  41,  60,  ...,  26,  25,  29],
#           ...,
#           [108, 112, 140,  ..., 116, 126, 126],
#           [119, 120, 148,  ..., 119, 124, 121],
#           [111, 111, 143,  ..., 120, 125, 122]]]),
#  TensorBBox([[220.1700, 257.3400, 283.0800, 315.4600]]),
#  'bear')

# %%
d[0][0].shape
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# Problem found: dls.decode_batch() is returning 224\*224 ims, but bboxes that can be as large as the original im.
#
# Need to investigate:
# - is Resize's decode failing for ims, but not for bboxes?
#
# Potential solutions:
# - transform ims to 224\*224 before dls pipeline processing
# - create new transforms that properly decode bboxes and ims
# - patch Resize's decodes

# %%
ab = dss.train[0][0],dss.train[0][1]
ab
# Out:
# (PILImage mode=RGB size=480x640,
#  TensorBBox([[143.5300, 189.3300, 275.5100, 360.7600]]))

# %%
pipe = Pipeline([PointScaler(),
                 Resize(im_size, method='squish')])

# %%
xy = pipe(ab)
xy
# Out:
# (TensorImage([[[254, 254, 255,  ..., 255, 255, 255],
#           [255, 255, 255,  ..., 255, 255, 255],
#           [255, 255, 255,  ..., 255, 255, 255],
#           ...,
#           [255, 254, 254,  ..., 254, 255, 255],
#           [254, 254, 254,  ..., 255, 255, 255],
#           [255, 254, 254,  ..., 255, 255, 255]],
#
#          [[254, 254, 255,  ..., 255, 255, 255],
#           [255, 255, 255,  ..., 255, 255, 255],
#           [255, 255, 255,  ..., 255, 255, 255],
#           ...,
#           [255, 254, 254,  ..., 254, 255, 255],
#           [254, 254, 254,  ..., 255, 255, 255],
#           [255, 254, 254,  ..., 255, 255, 255]],
#
#          [[254, 254, 255,  ..., 255, 255, 255],
#           [255, 255, 255,  ..., 255, 255, 255],
#           [255, 255, 255,  ..., 255, 255, 255],
#           ...,
#           [255, 254, 253,  ..., 254, 255, 255],
#           [254, 253, 253,  ..., 255, 255, 255],
#           [254, 252, 252,  ..., 255, 255, 255]]], dtype=torch.uint8),
#  TensorBBox([[-0.4020, -0.4083,  0.1480,  0.1274]]))

# %%
ctx = ab[0].show()
ab[1].show(ctx=ctx)
# Out:
# <AxesSubplot:>

# %%
ctx = xy[0].show()
xy[1].show(ctx=ctx)
# Out:
# <AxesSubplot:>

# %%
xy_d = pipe.decode(xy)
xy_d[0].shape, xy_d[1]
# Out:
# (torch.Size([3, 224, 224]),
#  TensorBBox([[143.5300, 189.3300, 275.5100, 360.7600]]))

# %%
pointscaler = PointScaler()
pointscaler
# Out:
# PointScaler:
# encodes: (TensorBBox,object) -> encodes
# (TensorImageBase,object) -> encodes
# (PILBase,object) -> encodes
# (TensorPoint,object) -> encodes
# decodes: (TensorBBox,object) -> decodes
# (TensorImageBase,object) -> decodes
# (PILBase,object) -> decodes
# (TensorPoint,object) -> decodes

# %%
resize = Resize(im_size, method='squish')
resize
# Out:
# Resize -- {'size': (224, 224), 'method': 'squish', 'pad_mode': 'reflection', 'resamples': (2, 0), 'p': 1.0}:
# encodes: (TensorBBox,object) -> encodes
# (TensorPoint,object) -> encodes
# (Image,object) -> encodes
# decodes:

# %% [markdown]
# Woah! This has no decodes!

# %%
@Resize
def decodes(self, x:int): pass

# %%
resize = Resize(im_size, method='squish')
resize
# Out:
# Resize -- {'size': (224, 224), 'method': 'squish', 'pad_mode': 'reflection', 'resamples': (2, 0), 'p': 1.0}:
# encodes: (TensorBBox,object) -> encodes
# (TensorPoint,object) -> encodes
# (Image,object) -> encodes
# decodes: (int,object) -> decodes

# %% [markdown]
# Thought: can I use a setup to create a dict that maps tfmd images to untfmd images? That way I could use decodes to get item via that dict.

# %%
doc(Resize)

# %% [markdown]
# According to sgugger, decodes is only implemented when necissary for making show methods work. Read: decodes is not implemented for data augmentation transforms. (src: https://forums.fast.ai/t/v2-images-questions-on-how-to-get-predictions-properly-multilple-sources-with-diff/63314/45). Seb suggests that visualizing the dataset is preferable to visualizing the batch in this case, but I want to visualize the transforms.

# %% [markdown]
# Maybe I should resize my bbox to 224*224 before the other transforms..? That would probably do the trick.

# %% [markdown]
# **left off here**

# %% [markdown]
# ## Model

# %%
### Model ###
class custom_module(Module):
    def __init__(self, body, head):
        self.body, self.head = body, head

    def forward(self, x):
        return self.head(self.body(x)) 
body = create_body(resnet34, pretrained=True)
head = create_head(1024, 4+dss.c, ps=0.5)
mod  = custom_module(body, head)


### Loss ###
# make this a class that finds alpha, beta, and gamma on init
def lbb_loss(pred, targ_bb, targ_lbl):
    mse = MSELossFlat()(pred[:,:4], torch.squeeze(targ_bb))
    cel = CrossEntropyLossFlat()(pred[:,4:], targ_lbl)
    alpha, beta, gamma = 1,10,1
    return mse*alpha + cel*beta*gamma

# %%
### Metrics ###
# See https://github.com/fastai/fastai/blob/715c027b0ad8586feda09e29fb2b483dfe30c910/fastai/learner.py#L344
# class Met(Metric):
#     @property
#     def value(self): return 1
    
# def lbb_acc(inp, targ, axis=-1):
#     pred,targ = flatten_check(inp[:,4:].argmax(dim=axis), targ)
#     return (pred == targ).float().mean()

# %% [markdown]
# ## Train

# %%
learner = Learner(dls, mod, loss_func=lbb_loss)
lr_min, _ = learner.lr_find(); lr_min
# Out:
# 0.0005248074419796466

# %% [markdown]
# Learning rates:
# - mse only: 1e-2
# - cel only: 5e-4
# - combined: 5e-4
#
# Min loss achieved after 8 epochs: 1.881

# %%
learner.fit_one_cycle(8, lr=5e-4) # mse only: lr=1e-2 ; cel only: lr=5e-4 ; both: 5e-4
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.360219</td>
#       <td>5.940746</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.658722</td>
#       <td>13.928998</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.026545</td>
#       <td>3.680221</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.008125</td>
#       <td>4.767646</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.671132</td>
#       <td>2.884153</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.845504</td>
#       <td>2.575560</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.396351</td>
#       <td>1.894666</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.239645</td>
#       <td>1.881281</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.show_results()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-53ff49a39b78> in <module>
# ----> 1 learner.show_results()
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastai/learner.py in show_results(self, ds_idx, dl, max_n, shuffle, **kwargs)
#     259         b = dl.one_batch()
#     260         _,_,preds = self.get_preds(dl=[b], with_decoded=True)
# --> 261         self.dls.show_results(b, preds, max_n=max_n, **kwargs)
#     262
#     263     def show_training_loop(self):
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastai/data/core.py in show_results(self, b, out, max_n, ctxs, show, **kwargs)
#     106         x,y,its = self.show_batch(b, max_n=max_n, show=False)
#     107         b_out = type(b)(b[:self.n_inp] + (tuple(out) if is_listy(out) else (out,)))
# --> 108         x1,y1,outs = self.show_batch(b_out, max_n=max_n, show=False)
#     109         res = (x,x1,None,None) if its is None else (x, y, its, outs.itemgot(slice(self.n_inp,None)))
#     110         if not show: return res
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastai/data/core.py in show_batch(self, b, max_n, ctxs, show, unique, **kwargs)
#      99             self.get_idxs = lambda: Inf.zeros
#     100         if b is None: b = self.one_batch()
# --> 101         if not show: return self._pre_show_batch(b, max_n=max_n)
#     102         show_batch(*self._pre_show_batch(b, max_n=max_n), ctxs=ctxs, max_n=max_n, **kwargs)
#     103         if unique: self.get_idxs = old_get_idxs
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastai/data/core.py in _pre_show_batch(self, b, max_n)
#      90         b = self.decode(b)
#      91         if hasattr(b, 'show'): return b,None,None
# ---> 92         its = self._decode_batch(b, max_n, full=False)
#      93         if not is_listy(b): b,its = [b],L((o,) for o in its)
#      94         return detuplify(b[:self.n_inp]),detuplify(b[self.n_inp:]),its
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastai/data/core.py in _decode_batch(self, b, max_n, full)
#      84         f = self.after_item.decode
#      85         f = compose(f, partial(getattr(self.dataset,'decode',noop), full = full))
# ---> 86         return L(batch_to_samples(b, max_n=max_n)).map(f)
#      87
#      88     def _pre_show_batch(self, b, max_n=9):
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in map(self, f, *args, **kwargs)
#     270              else f.format if isinstance(f,str)
#     271              else f.__getitem__)
# --> 272         return self._new(map(g, self))
#     273
#     274     def filter(self, f, negate=False, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in _new(self, items, *args, **kwargs)
#     216     @property
#     217     def _xtra(self): return None
# --> 218     def _new(self, items, *args, **kwargs): return type(self)(items, *args, use_list=None, **kwargs)
#     219     def __getitem__(self, idx): return self._get(idx) if is_indexer(idx) else L(self._get(idx), use_list=None)
#     220     def copy(self): return self._new(self.items.copy())
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in __call__(cls, x, *args, **kwargs)
#     197     def __call__(cls, x=None, *args, **kwargs):
#     198         if not args and not kwargs and x is not None and isinstance(x,cls): return x
# --> 199         return super().__call__(x, *args, **kwargs)
#     200
#     201 # Cell
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in __init__(self, items, use_list, match, *rest)
#     207         if items is None: items = []
#     208         if (use_list is not None) or not _is_array(items):
# --> 209             items = list(items) if use_list else _listify(items)
#     210         if match is not None:
#     211             if is_coll(match): match = len(match)
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in _listify(o)
#     114     if isinstance(o, list): return o
#     115     if isinstance(o, str) or _is_array(o): return [o]
# --> 116     if is_iter(o): return list(o)
#     117     return [o]
#     118
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in __call__(self, *args, **kwargs)
#     177             if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     178         fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 179         return self.fn(*fargs, **kwargs)
#     180
#     181 # Cell
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/utils.py in _inner(x, *args, **kwargs)
#     392     if order is not None: funcs = funcs.sorted(order)
#     393     def _inner(x, *args, **kwargs):
# --> 394         for f in L(funcs): x = f(x, *args, **kwargs)
#     395         return x
#     396     return _inner
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastai/data/core.py in decode(self, o, full)
#     320     def __iter__(self): return (self[i] for i in range(len(self)))
#     321     def __repr__(self): return coll_repr(self)
# --> 322     def decode(self, o, full=True): return tuple(tl.decode(o_, full=full) for o_,tl in zip(o,tuplify(self.tls, match=o)))
#     323     def subset(self, i): return type(self)(tls=L(tl.subset(i) for tl in self.tls), n_inp=self.n_inp)
#     324     def _new(self, items, *args, **kwargs): return super()._new(items, tfms=self.tfms, do_setup=False, **kwargs)
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastai/data/core.py in <genexpr>(.0)
#     320     def __iter__(self): return (self[i] for i in range(len(self)))
#     321     def __repr__(self): return coll_repr(self)
# --> 322     def decode(self, o, full=True): return tuple(tl.decode(o_, full=full) for o_,tl in zip(o,tuplify(self.tls, match=o)))
#     323     def subset(self, i): return type(self)(tls=L(tl.subset(i) for tl in self.tls), n_inp=self.n_inp)
#     324     def _new(self, items, *args, **kwargs): return super()._new(items, tfms=self.tfms, do_setup=False, **kwargs)
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastai/data/core.py in decode(self, o, **kwargs)
#     244     def __iter__(self): return (self[i] for i in range(len(self)))
#     245     def show(self, o, **kwargs): return self.tfms.show(o, **kwargs)
# --> 246     def decode(self, o, **kwargs): return self.tfms.decode(o, **kwargs)
#     247     def __call__(self, o, **kwargs): return self.tfms.__call__(o, **kwargs)
#     248     def overlapping_splits(self): return L(Counter(self.splits.concat()).values()).filter(gt(1))
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/transform.py in decode(self, o, full)
#     208         for f in reversed(self.fs):
#     209             if self._is_showable(o): return o
# --> 210             o = f.decode(o, split_idx=self.split_idx)
#     211         return o
#     212
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/transform.py in decode(self, x, **kwargs)
#      72     def name(self): return getattr(self, '_name', _get_name(self))
#      73     def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
# ---> 74     def decode  (self, x, **kwargs): return self._call('decodes', x, **kwargs)
#      75     def __repr__(self): return f'{self.name}:\nencodes: {self.encodes}decodes: {self.decodes}'
#      76
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/transform.py in _call(self, fn, x, split_idx, **kwargs)
#      81     def _call(self, fn, x, split_idx=None, **kwargs):
#      82         if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 83         return self._do_call(getattr(self, fn), x, **kwargs)
#      84
#      85     def _do_call(self, f, x, **kwargs):
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/transform.py in _do_call(self, f, x, **kwargs)
#      87             if f is None: return x
#      88             ret = f.returns_none(x) if hasattr(f,'returns_none') else None
# ---> 89             return retain_type(f(x, **kwargs), x, ret)
#      90         res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#      91         return retain_type(res, x)
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/dispatch.py in __call__(self, *args, **kwargs)
#     110         if not f: return args[0]
#     111         if self.inst is not None: f = MethodType(f, self.inst)
# --> 112         return f(*args, **kwargs)
#     113
#     114     def __get__(self, inst, owner):
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastai/data/transforms.py in decodes(self, o)
#     239
#     240     def encodes(self, o): return TensorCategory(self.vocab.o2i[o])
# --> 241     def decodes(self, o): return Category      (self.vocab    [o])
#     242
#     243 # Cell
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in __getitem__(self, k)
#     187     def __init__(self, items): self.items = items
#     188     def __len__(self): return len(self.items)
# --> 189     def __getitem__(self, k): return self.items[list(k) if isinstance(k,CollBase) else k]
#     190     def __setitem__(self, k, v): self.items[list(k) if isinstance(k,CollBase) else k] = v
#     191     def __delitem__(self, i): del(self.items[i])
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in __getitem__(self, idx)
#     217     def _xtra(self): return None
#     218     def _new(self, items, *args, **kwargs): return type(self)(items, *args, use_list=None, **kwargs)
# --> 219     def __getitem__(self, idx): return self._get(idx) if is_indexer(idx) else L(self._get(idx), use_list=None)
#     220     def copy(self): return self._new(self.items.copy())
#     221
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in _get(self, i)
#     225         return (self.items.iloc[list(i)] if hasattr(self.items,'iloc')
#     226                 else self.items.__array__()[(i,)] if hasattr(self.items,'__array__')
# --> 227                 else [self.items[i_] for i_ in i])
#     228
#     229     def __setitem__(self, idx, o):
#
# ~/.pyenv/versions/anaconda3-2020.02/lib/python3.7/site-packages/fastcore/foundation.py in <listcomp>(.0)
#     225         return (self.items.iloc[list(i)] if hasattr(self.items,'iloc')
#     226                 else self.items.__array__()[(i,)] if hasattr(self.items,'__array__')
# --> 227                 else [self.items[i_] for i_ in i])
#     228
#     229     def __setitem__(self, idx, o):
#
# IndexError: list index out of range

# %% [markdown]
# ## View Results

# %%
### View Results ###
# get preds
ib,bb,lb = dls.one_batch()
preds = learner.model(ib)
pred_bbs = preds[:,:4]
pred_lbls = preds[:,4:].argmax(dim=-1)

# show n preds
n=16
nrows=4
ncols=4
start_idx=0

ctxs = get_grid(n, nrows, ncols)
for i,ctx in enumerate(ctxs):
    idx = start_idx+i
    # title
    pred_title=dls.vocab[pred_lbls[idx].item()]
    act_title=dls.vocab[lb[idx].item()]
    got_it='✔️' if pred_title==act_title else '✖️'
    title=f"{got_it}  P {pred_title} : A {act_title}"
    # im
    show_image(ib[idx], ctx=ctx, title=title)
    # bbs
    pred_bb = TensorBBox(pred_bbs[idx])
    targ_bb = TensorBBox(bb[idx])
    ((pred_bb+1)*224//2).show(ctx=ctx, color='magenta')
    ((targ_bb+1)*224//2).show(ctx=ctx);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Making show_results work (from siamese tutorial)

# %%
@typedispatch
def show_results(x:SiameseImage, y, samples, outs, ctxs=None, max_n=6, nrows=None, ncols=2, figsize=None, **kwargs):
    if figsize is None: figsize = (ncols*6, max_n//ncols * 3)
    if ctxs is None: ctxs = get_grid(min(x[0].shape[0], max_n), nrows=None, ncols=ncols, figsize=figsize)
    for i,ctx in enumerate(ctxs): 
        title  = f'Actual: {["Not similar","Similar"][x[2][i].item()]} \n'
        title += f'Prediction: {["Not similar","Similar"][y[2][i].item()]}'
        SiameseImage(x[0][i], x[1][i], title).show(ctx=ctx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5f48f4dbe45a> in <module>
#       1 @typedispatch
# ----> 2 def show_results(x:SiameseImage, y, samples, outs, ctxs=None, max_n=6, nrows=None, ncols=2, figsize=None, **kwargs):
#       3     if figsize is None: figsize = (ncols*6, max_n//ncols * 3)
#       4     if ctxs is None: ctxs = get_grid(min(x[0].shape[0], max_n), nrows=None, ncols=ncols, figsize=figsize)
#       5     for i,ctx in enumerate(ctxs):
#
# NameError: name 'SiameseImage' is not defined

# %% [markdown]
# ## Notes & Work

# %% [markdown]
# ### Loss Notes

# %% [markdown]
# My notes from my journal
# 1. `xb,yb = b`
# 2. `p = mod(xb)`
# 3. `alpha = cel(mb) / rmse(mb); beta = 1`
# 4. `if epoch <= 3: gamma=10; else: gamma=1` (do later)
# 5. `loss(p, yb): rmse(p[0:4],yb[0])*alpha*gamma + cel(p[4:],yb[1])*beta`

# %% [markdown]
# Method chain for learning (from https://github.com/fastai/fastai/blob/master/fastai/learner.py#L163)
# 1. `learner.fit_one_cycle()`
# 2. → `.fit()`
# 3. → `._do_fit()`
# 4. → `._do_epoch()`
# 5. → `._do_epoch_train(); ._do_epoch_validate()` (rest of chain follows `_do_epoch_train`)
# 6. → `.dl = .dls.train; .all_batches()`
# 7. → `.n_iter = len(.dl); for o in enum(.dl): .one_batch(*o)` o=(i,b)
# 8. → `.iter = i; ._split(b); ._do_one_batch()` (item 9 has `_split`, item 10 has `_do_one_batch`)
# 9. → `._split(b)`: `i = dls.n_inp; .xb, .yb = b[:i], b[i:]`
# 10. → `._do_one_batch()`:
#     - `.pred = .model(*xb)`
#     - `.loss = .loss_func(.pred, *.yb)`
#     - `._backward()` → `.loss.backward()`
#     - `._step()` → `.opt.step()`
#     - `.opt.zero_grad()`

# %% [markdown]
# ### Loss Work

# %%
learner = Learner(dls, mod, loss_func=lbb_loss)
learner.dl = learner.dls.train
learner.b  = learner.dl.one_batch()
learner._split(learner.b)

# %%
learner.pred = learner.model(learner.xb[0])

# %%
learner.pred.shape
# Out:
# torch.Size([64, 12])

# %%
learner.pred[0]
# Out:
# tensor([-0.1258,  0.3672,  0.5901, -0.1777, -0.8904,  0.7933,  0.2428,  1.9469,
#         -0.5976, -1.0789, -1.2176, -0.4324], device='cuda:0',
#        grad_fn=<SelectBackward>)

# %%
learner.yb[0].shape
# Out:
# torch.Size([64, 1, 4])

# %%
[learner.yb[0].shape[0], learner.yb[0].shape[-1]]
# Out:
# [64, 4]

# %%
learner.yb
# Out:
# (TensorBBox([[[-0.2176, -0.0629, -0.0134,  0.2128]],
#
#          [[-0.2596, -0.8973,  0.3544,  0.9628]],
#
#          [[-1.0000, -0.3716,  0.9917,  0.3761]],
#
#          [[-0.6538, -0.5697,  0.7310,  0.8563]],
#
#          [[-0.4638, -0.3515,  0.3256,  0.1168]],
#
#          [[-0.5657, -0.4710,  0.0906, -0.0882]],
#
#          [[-0.0990, -0.6553,  0.4875, -0.2109]],
#
#          [[-0.9313, -0.3214,  0.9131,  0.4786]],
#
#          [[-0.4485,  0.0178, -0.3423,  0.2311]],
#
#          [[-0.7116, -0.4122,  0.3024,  0.3671]],
#
#          [[-0.5355, -0.5242,  0.4081,  0.5527]],
#
#          [[-0.9284, -0.5109,  0.9340,  0.4554]],
#
#          [[-0.4018, -0.4036,  0.5217,  0.4458]],
#
#          [[-0.7367,  0.0744, -0.5844,  0.2837]],
#
#          [[-1.0000, -0.9713,  0.8297,  1.0000]],
#
#          [[-0.3388, -0.6430, -0.1341, -0.5146]],
#
#          [[-0.9924, -0.1374,  0.7230,  0.3086]],
#
#          [[-0.7736,  0.4367, -0.0809,  1.0000]],
#
#          [[-0.0785, -0.4619,  0.7832,  0.2556]],
#
#          [[-0.8504, -0.8671,  0.9277,  1.0000]],
#
#          [[-0.7168, -0.0292,  0.9685,  0.6674]],
#
#          [[-0.9340, -0.3124,  0.9251,  0.4337]],
#
#          [[-0.9582, -0.0628,  0.9190,  0.3587]],
#
#          [[-0.4542, -0.2821,  0.5953,  0.3931]],
#
#          [[-0.9947, -0.7470, -0.4878,  0.3361]],
#
#          [[-0.6138,  0.1200, -0.3926,  0.4012]],
#
#          [[-0.9274, -0.9914,  0.9981,  0.9672]],
#
#          [[-0.7843, -0.4022,  0.8472,  0.4472]],
#
#          [[-0.5037,  0.1187,  0.4360,  1.0000]],
#
#          [[-1.0000, -1.0000,  0.9899,  0.9919]],
#
#          [[-0.4118, -0.4749,  0.4502,  0.1030]],
#
#          [[-0.8431, -0.6516,  0.8209,  0.9398]],
#
#          [[-0.0785, -0.7955,  0.9137,  0.9758]],
#
#          [[-0.6543, -0.3895,  0.2293,  0.4015]],
#
#          [[-0.0557,  0.0612,  0.1686,  0.3840]],
#
#          [[-0.9850, -0.9955,  0.4180,  1.0000]],
#
#          [[-0.9957, -0.8633,  0.1020, -0.3829]],
#
#          [[-0.2042, -0.5289, -0.0802, -0.3425]],
#
#          [[-0.9358, -0.2500,  0.9245,  0.4347]],
#
#          [[-0.9039, -0.2496,  0.5719,  0.3835]],
#
#          [[-0.9880, -0.4865,  0.8337,  0.1337]],
#
#          [[-0.3283, -0.5452,  0.4910,  0.3081]],
#
#          [[-0.3146, -0.8033,  0.1797,  0.1317]],
#
#          [[-0.4764, -0.3601,  0.4185,  0.3663]],
#
#          [[-0.4337, -0.6135,  0.5281,  0.4697]],
#
#          [[ 0.0245, -0.3368,  0.8781,  0.9078]],
#
#          [[-0.4233, -0.9955,  0.6831, -0.2466]],
#
#          [[-0.8545, -0.0695,  0.8784,  0.7573]],
#
#          [[-0.2880, -0.2445,  0.2162,  0.4498]],
#
#          [[-0.2897, -0.9605,  0.5049,  0.8273]],
#
#          [[-0.4026, -0.5842,  0.0150,  0.8077]],
#
#          [[-0.9933, -0.9873,  0.0241,  0.9678]],
#
#          [[ 0.7458,  0.2646,  0.9913,  0.6774]],
#
#          [[-0.9899, -0.7832,  0.9989,  0.7674]],
#
#          [[-0.9426, -0.6915,  0.7770,  0.5923]],
#
#          [[ 0.3479, -0.1909,  0.9339,  0.1129]],
#
#          [[-0.6070, -0.9641,  0.3816,  0.5011]],
#
#          [[-0.3828, -0.5828,  0.5281,  0.9768]],
#
#          [[-0.2689, -0.0416,  0.0790,  0.9652]],
#
#          [[-0.0212,  0.3770,  0.0582,  0.5228]],
#
#          [[-0.2241, -0.3525,  0.2778,  0.2786]],
#
#          [[-0.8173, -1.0000,  0.5675,  0.9982]],
#
#          [[-0.6216,  0.0033,  0.3513,  0.6396]],
#
#          [[-0.3412, -0.4061, -0.2444, -0.2192]]], device='cuda:0'),
#  TensorCategory([3, 4, 0, 5, 1, 2, 5, 0, 7, 7, 2, 0, 7, 5, 6, 3, 7, 6, 1, 1, 7, 0, 7, 0,
#          0, 5, 3, 7, 6, 3, 3, 2, 3, 1, 2, 7, 7, 3, 0, 0, 7, 1, 3, 1, 6, 6, 5, 0,
#          3, 4, 2, 7, 2, 0, 6, 0, 5, 4, 4, 2, 0, 4, 5, 3], device='cuda:0'))

# %%
learner.pred[:,4:].shape
# Out:
# torch.Size([64, 8])

# %%
(learner.pred[:,4:]).argmax(dim=-1)
# Out:
# tensor([3, 4, 0, 5, 1, 0, 5, 0, 7, 1, 0, 0, 7, 5, 6, 3, 7, 6, 1, 1, 1, 0, 0, 0,
#         0, 5, 3, 7, 6, 0, 6, 2, 3, 1, 1, 0, 3, 3, 0, 0, 7, 3, 3, 1, 6, 6, 5, 0,
#         3, 4, 2, 6, 0, 0, 6, 0, 5, 1, 4, 0, 0, 1, 5, 3], device='cuda:0')

# %%
torch.squeeze(learner.yb[0]).shape
# Out:
# torch.Size([64, 4])

# %%
learner.metrics
# Out:
# (#0) []

# %%
def cel_loss(pred, targ_bb, targ_lbl):
#     mse = MSELossFlat()(pred[:,:4], torch.squeeze(targ_bb))
    cel = CrossEntropyLossFlat()(pred[:,4:], targ_lbl)
    return cel

# %%
lbb_loss(learner.pred, learner.yb[0], learner.yb[1])
# Out:
# tensor(2.0821, device='cuda:0', grad_fn=<NllLossBackward>)
